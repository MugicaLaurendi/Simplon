# %%
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
data_alcohol = pd.read_csv("Data/russia_alcohol.csv")
data_demography = pd.read_csv("Data/russian_demography.csv")

# %%
data = data_demography.merge(data_alcohol)
data
# Out:
#       year                          region   npg  birth_rate  death_rate  \
# 0     1998              Republic of Adygea  -4.3         9.6        13.9
# 1     1998                      Altai Krai  -4.0         8.8        12.8
# 2     1998                     Amur Oblast  -1.8        10.4        12.2
# 3     1998              Arkhangelsk Oblast  -4.2         9.1        13.3
# 4     1998                Astrakhan Oblast  -3.7         9.6        13.3
# ...    ...                             ...   ...         ...         ...
# 1610  2016                Chuvash Republic   0.0        13.2        13.2
# 1611  2016       Chukotka Autonomous Okrug   3.6        13.6        10.0
# 1612  2016        Sakha (Yakutia) Republic   7.6        16.0         8.4
# 1613  2016  Yamalo-Nenets Autonomous Okrug  10.1        15.4         5.3
# 1614  2016                Yaroslavl Oblast  -3.6        12.1        15.7
#
#         gdw  urbanization  wine  beer  vodka  champagne  brandy
# ...

# %%
(data.isna().sum()/data.__len__())*100
# Out:
# year            0.000000
# region          0.000000
# npg             2.291022
# birth_rate      2.291022
# death_rate      2.414861
# gdw             2.105263
# urbanization    2.105263
# wine            3.900929
# beer            3.591331
# vodka           3.777090
# champagne       3.900929
# brandy          4.086687
# dtype: float64

# %%
total_alcohol_column = data["wine"] + data["beer"] + data["vodka"] + data["champagne"] + data["brandy"]

data["total_alcohol"] = total_alcohol_column
data
# Out:
#       year                          region   npg  birth_rate  death_rate  \
# 0     1998              Republic of Adygea  -4.3         9.6        13.9
# 1     1998                      Altai Krai  -4.0         8.8        12.8
# 2     1998                     Amur Oblast  -1.8        10.4        12.2
# 3     1998              Arkhangelsk Oblast  -4.2         9.1        13.3
# 4     1998                Astrakhan Oblast  -3.7         9.6        13.3
# ...    ...                             ...   ...         ...         ...
# 1610  2016                Chuvash Republic   0.0        13.2        13.2
# 1611  2016       Chukotka Autonomous Okrug   3.6        13.6        10.0
# 1612  2016        Sakha (Yakutia) Republic   7.6        16.0         8.4
# 1613  2016  Yamalo-Nenets Autonomous Okrug  10.1        15.4         5.3
# 1614  2016                Yaroslavl Oblast  -3.6        12.1        15.7
#
#         gdw  urbanization  wine  beer  vodka  champagne  brandy  sum_alcohol  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1615 entries, 0 to 1614
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           1615 non-null   int64
#  1   region         1615 non-null   object
#  2   npg            1578 non-null   float64
#  3   birth_rate     1578 non-null   float64
#  4   death_rate     1576 non-null   float64
#  5   gdw            1581 non-null   float64
#  6   urbanization   1581 non-null   float64
#  7   wine           1552 non-null   float64
#  8   beer           1557 non-null   float64
#  9   vodka          1554 non-null   float64
#  10  champagne      1552 non-null   float64
#  11  brandy         1549 non-null   float64
#  12  sum_alcohol    1549 non-null   float64
#  13  total_alcohol  1549 non-null   float64
# dtypes: float64(12), int64(1), object(1)
# memory usage: 189.3+ KB

# %%
data["region"].value_counts()
# Out:
# Republic of Adygea            19
# Komi Republic                 19
# Sverdlovsk Oblast             19
# Sakhalin Oblast               19
# Saratov Oblast                19
#                               ..
# Kirov Oblast                  19
# Kemerovo Oblast               19
# Republic of Karelia           19
# Karachay-Cherkess Republic    19
# Yaroslavl Oblast              19
# Name: region, Length: 85, dtype: int64
