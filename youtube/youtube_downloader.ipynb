# %%
# !pip install openai
# !pip install deepl
# !pip install youtube_dl
# Out:
# Running cells with 'c:\Users\utilisateur\AppData\Local\Microsoft\WindowsApps\python3.10.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/utilisateur/AppData/Local/Microsoft/WindowsApps/python3.10.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import youtube_dl
import openai
import deepl

# %%
ydl_opts = {}
with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    ydl.download(['https://www.youtube.com/watch?v=Wqs4i1gUw9Q'])
# Out:
# [youtube] Wqs4i1gUw9Q: Downloading webpage
# ERROR: Unable to extract uploader id; please report this issue on https://yt-dl.org/bug . Make sure you are using the latest version; see  https://yt-dl.org/update  on how to update. Be sure to call youtube-dl with the --verbose flag and include its complete output.
# ---------------------------------------------------------------------------
# RegexNotFoundError                        Traceback (most recent call last)
# ~/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in wrapper(self, *args, **kwargs)
#     814             try:
# --> 815                 return func(self, *args, **kwargs)
#     816             except GeoRestrictedError as e:
#
# ~/.pyenv/versions/3.8.12/envs/simplon/lib/python3.8/site-packages/youtube_dl/YoutubeDL.py in __extract_info(self, url, ie, download, extra_info, process)
#     835     def __extract_info(self, url, ie, download, extra_info, process):
# ...

# %%
audio_file= open("oss_repliques.mp3", "rb")
openai.api_key = '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'
transcript = openai.Audio.transcribe("whisper-1", audio_file)

#print(transcript)
# Out:
# {
# ...

# %%
bob = transcript["text"]

bob2 = bob.replace(". ", ".\n")
bob2 = bob2.replace("? ", ".\n")
bob2 = bob2.replace("! ", ".\n")
#print(bob2)

# %%
print(bob2)
# Out:
# Le problème avec l'arabe, c'est que ce n'est pas facilement lisible.
# Même au niveau du son, on sent...
# Oui, non mais c'est joli, c'est joli quand même.
# L'arabe est parlé par des millions de personnes.
# Et son écriture est un art.
# Des millions.
# Des millions, vous êtes charmante.
# Vous voyez ce que ça fait déjà un million, Larmina.
# Vous voyez l'automobile derrière moi.
# Oui.
# Ça fait un petit moment que je l'observe.
# Et bien.
# Et bien, elle est absolument impeccable.
# C'est quand même bien mieux une voiture propre, non.
# À l'occasion, je vous mettrai un petit coup de polish.
# J'aime me battre.
# Fais-moi l'amour.
# Non, je ne crois pas, non.
# Pourquoi.
# Pas envie.
# Les ânes partout, les djellabas, l'écriture égypte, ça...
# Ça, j'irai te grandir.
# Ça, j'irai te grandir.
# C'est marrant que c'est toujours les nazis qui ont les mauvais rôles.
# Nous sommes en 1955, Herr Barmahr.
# On peut avoir une deuxième chance.
# Merci.
# Oh, chaise.
# 23-0.
# ...

# %%
auth_key = "4c4edf95-8ccc-93ec-a1fb-4503f21f0967:fx"  # Replace with your key
translator = deepl.Translator(auth_key)

result = translator.translate_text(bob2, target_lang="EN-GB")
print(result.text)  # "Bonjour, le monde !"
# Out:
# The problem with Arabic is that it's not easily readable.
# Even in terms of sound, you can feel...
# Yes, no, but it's nice, it's nice anyway.
# Arabic is spoken by millions of people.
# And its writing is an art.
# Millions of people.
# Millions, you are charming.
# You see what a million is, Larmina.
# You see the car behind me.
# Yes.
# I've been watching it for a while.
# I've been watching it for a while.
# Well, it's absolutely spotless.
# It's much better to have a clean car, isn't it?
# I'll give it a polish every now and then.
# I like to fight.
# Make love to me.
# No, I don't think so.
# Why not?
# I don't want to.
# Donkeys everywhere, the djellabas, the Egyptian writing, that...
# That, I'll grow you up.
# I'll grow up with that.
# It's funny that it's always the Nazis who get the bad parts.
# This is 1955, Herr Barmahr.
# We can have a second chance.
# Thank you.
# Oh, chair.
# 23-0.
# That's the piquette, Jack.
# You can't play, Jack.
# You're bad.
# Jack.
# Yes.
# ...
