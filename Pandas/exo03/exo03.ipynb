# %%
import pandas as pd

import matplotlib

csv = "artworks_copy.csv"

df = pd.read_csv(csv)

# %%
(df.count()/df.shape[0] * 100)
# Out:
# Artwork ID            100.000000
# Title                  99.960080
# Artist ID              98.879182
# Name                   98.879182
# Date                   98.225116
# Medium                 90.849979
# Dimensions             91.200043
# Acquisition Date       95.806145
# Credit                 97.643211
# Catalogue             100.000000
# Department            100.000000
# Classification        100.000000
# Object Number         100.000000
# Diameter (cm)           1.073989
# Circumference (cm)      0.007677
# Height (cm)            85.898420
# Length (cm)             0.565015
# Width (cm)             85.215182
# Depth (cm)              8.784603
# Weight (kg)             0.228770
# Duration (s)            2.367536
# dtype: float64

# %%
df_graph = df['Classification']
df_graph.value_counts().plot(kind="bar",title="Nombres d'oeuvre d'art par Classification", figsize=[20, 8], rot=80, legend=True, ylabel="Nombre d'oeuvre d'Art", xlabel="Catégorie", fontsize='large')
#df["Duration (s)"].value_counts().plot(title="Nombres d'oeuvre d'art par Classification", figsize=[20, 8], rot=45, legend=True, ylabel="Nombre d'oeuvre d'Art", xlabel="Catégorie", fontsize='large')
# Out:
# <AxesSubplot:title={'center':"Nombres d'oeuvre d'art par Classification"}, xlabel='Catégorie', ylabel="Nombre d'oeuvre d'Art">

# %%
data_classification = df[df.Classification =="Film"]
data_duration = df["Duration (s)"]

display(data_classification)
data_duration
# Out:
#         Artwork ID                                              Title  \
# 9632         10721                        Traces Suspectes en Surface
# 75832        82013                                     Felix in Exile
# 75833        82014                      History of the Main Complaint
# 81138        89256  Screen Tests: "Baby" Jane Holzer, Isabel Ebers...
# 81142        89260                                  The Text of Light
# ...            ...                                                ...
# 130207      217832                               La Dame aux camélias
# 130208      217833                                        Vanity Fair
# 130209      217834                           American Shooting Series
# 130210      217835                                            Blih-Ah
# 130211      217836                                               WMEN
#
#        Artist ID                 Name                     Date  \
# ...
