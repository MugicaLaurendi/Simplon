# %%
import pandas as pd
import matplotlib as mpl
import numpy as np

csv = "coin.csv"
df = pd.read_csv(csv)

df
# Out:
#                 Groupe 1 Groupe 2 Groupe 3  Groupe 4  Groupe 5 Groupe 6  \
# 0    Lancer n°1      -51       30       20       0.0        23       29
# 1    Lancer n°2     -107      -43      -16       2.0       101       67
# 2    Lancer n°3      -59   -123,5       37     -23.0        81       44
# 3    Lancer n°4    -94,5    -59,5      -29      -2.0        16       26
# 4    Lancer n°5      -64    -40,5        3       2.0       -41       88
# 5    Lancer n°6       30        5       43      78.0       -59      -51
# 6    Lancer n°7      -24       55      -21      70.0        -3      -63
# 7    Lancer n°8       -1     -8,5      -13      -7.0        12     20.5
# 8    Lancer n°9        3       87      -18      12.0      -140      -40
# 9   Lancer n°10       37     44,5       24      81.0       -85    -33.5
# 10  Lancer n°11      179    -62,5     13.5      20.0        10       30
# 11  Lancer n°12     86,5      -30       28      61.0        46       29
# ...

# %%
def clean(x) :
    x = x.replace(',','.')
    return x

df = df.apply(clean)
df
# Out:
#                 Groupe 1 Groupe 2 Groupe 3  Groupe 4  Groupe 5 Groupe 6  \
# 0    Lancer n°1      -51       30       20       0.0        23       29
# 1    Lancer n°2     -107      -43      -16       2.0       101       67
# 2    Lancer n°3      -59   -123,5       37     -23.0        81       44
# 3    Lancer n°4    -94,5    -59,5      -29      -2.0        16       26
# 4    Lancer n°5      -64    -40,5        3       2.0       -41       88
# 5    Lancer n°6       30        5       43      78.0       -59      -51
# 6    Lancer n°7      -24       55      -21      70.0        -3      -63
# 7    Lancer n°8       -1     -8,5      -13      -7.0        12     20.5
# 8    Lancer n°9        3       87      -18      12.0      -140      -40
# 9   Lancer n°10       37     44,5       24      81.0       -85    -33.5
# 10  Lancer n°11      179    -62,5     13.5      20.0        10       30
# 11  Lancer n°12     86,5      -30       28      61.0        46       29
# ...
